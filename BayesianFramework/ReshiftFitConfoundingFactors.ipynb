# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></div><div class="lev1 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Data</a></div><div class="lev1 toc-item"><a href="#Initial-plot-of-fit-results" data-toc-modified-id="Initial-plot-of-fit-results-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Initial plot of fit results</a></div><div class="lev3 toc-item"><a href="#Similar-plot-with-restricted-reshift-range" data-toc-modified-id="Similar-plot-with-restricted-reshift-range-301"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Similar plot with restricted reshift range</a></div><div class="lev1 toc-item"><a href="#Compute-and-plot-difference-between-true-and-best-fit-redshift" data-toc-modified-id="Compute-and-plot-difference-between-true-and-best-fit-redshift-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Compute and plot difference between true and best fit redshift</a></div><div class="lev1 toc-item"><a href="#Functions-to-plot-grids-of-fit-results-grouped-according-to-input-model-parameters" data-toc-modified-id="Functions-to-plot-grids-of-fit-results-grouped-according-to-input-model-parameters-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Functions to plot grids of fit results grouped according to input model parameters</a></div><div class="lev1 toc-item"><a href="#Grouped-Plots" data-toc-modified-id="Grouped-Plots-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Grouped Plots</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-stellar-population-AGE" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-stellar-population-AGE-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Best Fit <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-270-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3704" role="math" style="width: 1.441em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.176em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.669em, 1001.176em, 2.464em, -999.998em); top: -2.195em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3705"><span class="msubsup" id="MathJax-Span-3706"><span style="display: inline-block; position: relative; width: 1.138em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3707" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3708"><span class="mrow" id="MathJax-Span-3709"><span class="mi" id="MathJax-Span-3710" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.04em;"></span></span><span class="mi" id="MathJax-Span-3711" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3712" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.199em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-270">z_{\rm fit}</script> with all true <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-271-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3713" role="math" style="width: 1.934em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.593em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.669em, 1001.593em, 2.464em, -999.998em); top: -2.195em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3714"><span class="msubsup" id="MathJax-Span-3715"><span style="display: inline-block; position: relative; width: 1.555em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3716" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3717"><span class="mrow" id="MathJax-Span-3718"><span class="mi" id="MathJax-Span-3719" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3720" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3721" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3722" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.199em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-271">z_{\rm true}</script> values overlaid grouped by stellar population AGE</a></div><div class="lev2 toc-item"><a href="#Difference-($z_{\rm-fit}-z_{\rm-true}$)-values-grouped-by-stellar-population-AGE" data-toc-modified-id="Difference-($z_{\rm-fit}-z_{\rm-true}$)-values-grouped-by-stellar-population-AGE-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Difference (<span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-272-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3723" role="math" style="width: 4.699em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.903em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.972em, 1003.903em, 2.767em, -999.998em); top: -2.498em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3724"><span class="msubsup" id="MathJax-Span-3725"><span style="display: inline-block; position: relative; width: 1.138em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3726" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3727"><span class="mrow" id="MathJax-Span-3728"><span class="mi" id="MathJax-Span-3729" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.04em;"></span></span><span class="mi" id="MathJax-Span-3730" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3731" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span><span class="mo" id="MathJax-Span-3732" style="font-family: STIXMathJax_Main; padding-left: 0.267em;">−</span><span class="msubsup" id="MathJax-Span-3733" style="padding-left: 0.267em;"><span style="display: inline-block; position: relative; width: 1.555em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3734" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3735"><span class="mrow" id="MathJax-Span-3736"><span class="mi" id="MathJax-Span-3737" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3738" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3739" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3740" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.502em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub><mo>−</mo><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-272">z_{\rm fit}-z_{\rm true}</script>) values grouped by stellar population AGE</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-starburst-duration-AGE" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-starburst-duration-AGE-63"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Best Fit <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-273-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3741" role="math" style="width: 1.441em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.176em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.669em, 1001.176em, 2.464em, -999.998em); top: -2.195em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3742"><span class="msubsup" id="MathJax-Span-3743"><span style="display: inline-block; position: relative; width: 1.138em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3744" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3745"><span class="mrow" id="MathJax-Span-3746"><span class="mi" id="MathJax-Span-3747" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.04em;"></span></span><span class="mi" id="MathJax-Span-3748" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3749" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.199em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-273">z_{\rm fit}</script> with all true <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-274-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3750" role="math" style="width: 1.934em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.593em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.669em, 1001.593em, 2.464em, -999.998em); top: -2.195em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3751"><span class="msubsup" id="MathJax-Span-3752"><span style="display: inline-block; position: relative; width: 1.555em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3753" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3754"><span class="mrow" id="MathJax-Span-3755"><span class="mi" id="MathJax-Span-3756" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3757" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3758" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3759" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.199em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-274">z_{\rm true}</script> values overlaid grouped by starburst duration AGE</a></div><div class="lev2 toc-item"><a href="#Difference-($z_{\rm-fit}-z_{\rm-true}$)-values-grouped-by-starburst-duration-TAU" data-toc-modified-id="Difference-($z_{\rm-fit}-z_{\rm-true}$)-values-grouped-by-starburst-duration-TAU-64"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Difference (<span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-275-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3760" role="math" style="width: 4.699em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.903em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.972em, 1003.903em, 2.767em, -999.998em); top: -2.498em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3761"><span class="msubsup" id="MathJax-Span-3762"><span style="display: inline-block; position: relative; width: 1.138em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3763" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3764"><span class="mrow" id="MathJax-Span-3765"><span class="mi" id="MathJax-Span-3766" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.04em;"></span></span><span class="mi" id="MathJax-Span-3767" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3768" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span><span class="mo" id="MathJax-Span-3769" style="font-family: STIXMathJax_Main; padding-left: 0.267em;">−</span><span class="msubsup" id="MathJax-Span-3770" style="padding-left: 0.267em;"><span style="display: inline-block; position: relative; width: 1.555em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3771" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3772"><span class="mrow" id="MathJax-Span-3773"><span class="mi" id="MathJax-Span-3774" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3775" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3776" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3777" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.502em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub><mo>−</mo><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-275">z_{\rm fit}-z_{\rm true}</script>) values grouped by starburst duration TAU</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-METALLICITY_INDEX" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-METALLICITY_INDEX-65"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Best Fit <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-276-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3778" role="math" style="width: 1.441em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.176em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.669em, 1001.176em, 2.464em, -999.998em); top: -2.195em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3779"><span class="msubsup" id="MathJax-Span-3780"><span style="display: inline-block; position: relative; width: 1.138em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3781" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3782"><span class="mrow" id="MathJax-Span-3783"><span class="mi" id="MathJax-Span-3784" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.04em;"></span></span><span class="mi" id="MathJax-Span-3785" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3786" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.199em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-276">z_{\rm fit}</script> with all true <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-277-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3787" role="math" style="width: 1.934em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.593em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.669em, 1001.593em, 2.464em, -999.998em); top: -2.195em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3788"><span class="msubsup" id="MathJax-Span-3789"><span style="display: inline-block; position: relative; width: 1.555em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3790" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3791"><span class="mrow" id="MathJax-Span-3792"><span class="mi" id="MathJax-Span-3793" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3794" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3795" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3796" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.199em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-277">z_{\rm true}</script> values overlaid grouped by METALLICITY_INDEX</a></div><div class="lev2 toc-item"><a href="#Difference-($z_{\rm-fit}-z_{\rm-true}$)-values-grouped-by-METALLICITY-INDEX" data-toc-modified-id="Difference-($z_{\rm-fit}-z_{\rm-true}$)-values-grouped-by-METALLICITY-INDEX-66"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Difference (<span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-280-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3833" role="math" style="width: 4.699em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.903em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.972em, 1003.903em, 2.767em, -999.998em); top: -2.498em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3834"><span class="msubsup" id="MathJax-Span-3835"><span style="display: inline-block; position: relative; width: 1.138em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3836" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3837"><span class="mrow" id="MathJax-Span-3838"><span class="mi" id="MathJax-Span-3839" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.04em;"></span></span><span class="mi" id="MathJax-Span-3840" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3841" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span><span class="mo" id="MathJax-Span-3842" style="font-family: STIXMathJax_Main; padding-left: 0.267em;">−</span><span class="msubsup" id="MathJax-Span-3843" style="padding-left: 0.267em;"><span style="display: inline-block; position: relative; width: 1.555em; height: 0px;"><span style="position: absolute; clip: rect(3.487em, 1000.381em, 4.206em, -999.998em); top: -4.013em; left: 0.002em;"><span class="mi" id="MathJax-Span-3844" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; top: -3.862em; left: 0.381em;"><span class="texatom" id="MathJax-Span-3845"><span class="mrow" id="MathJax-Span-3846"><span class="mi" id="MathJax-Span-3847" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3848" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3849" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3850" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.502em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.225em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub><mo>−</mo><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-280">z_{\rm fit}-z_{\rm true}</script>) values grouped by METALLICITY INDEX</a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($z_{\rm-fit}-z_{\rm-true}$)-versus-SP-AGE-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($z_{\rm-fit}-z_{\rm-true}$)-versus-SP-AGE-and-$z_{\rm-true}$-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Plots of summary statistics of difference (<span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-283-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3887" role="math" style="width: 4.713em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.912em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.989em, 1003.912em, 2.758em, -999.998em); top: -2.498em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3888"><span class="msubsup" id="MathJax-Span-3889"><span style="display: inline-block; position: relative; width: 1.123em; height: 0px;"><span style="position: absolute; clip: rect(3.495em, 1000.386em, 4.2em, -999.998em); top: -4.005em; left: 0.002em;"><span class="mi" id="MathJax-Span-3890" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span><span style="position: absolute; top: -3.845em; left: 0.386em;"><span class="texatom" id="MathJax-Span-3891"><span class="mrow" id="MathJax-Span-3892"><span class="mi" id="MathJax-Span-3893" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.034em;"></span></span><span class="mi" id="MathJax-Span-3894" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3895" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span></span></span><span class="mo" id="MathJax-Span-3896" style="font-family: STIXMathJax_Main; padding-left: 0.258em;">−</span><span class="msubsup" id="MathJax-Span-3897" style="padding-left: 0.258em;"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px;"><span style="position: absolute; clip: rect(3.495em, 1000.386em, 4.2em, -999.998em); top: -4.005em; left: 0.002em;"><span class="mi" id="MathJax-Span-3898" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span><span style="position: absolute; top: -3.845em; left: 0.386em;"><span class="texatom" id="MathJax-Span-3899"><span class="mrow" id="MathJax-Span-3900"><span class="mi" id="MathJax-Span-3901" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3902" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3903" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3904" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.502em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.229em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.771em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub><mo>−</mo><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-283">z_{\rm fit}-z_{\rm true}</script>) versus SP AGE and <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-284-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3905" role="math" style="width: 1.925em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.604em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.7em, 1001.604em, 2.47em, -999.998em); top: -2.21em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3906"><span class="msubsup" id="MathJax-Span-3907"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px;"><span style="position: absolute; clip: rect(3.495em, 1000.386em, 4.2em, -999.998em); top: -4.005em; left: 0.002em;"><span class="mi" id="MathJax-Span-3908" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span><span style="position: absolute; top: -3.845em; left: 0.386em;"><span class="texatom" id="MathJax-Span-3909"><span class="mrow" id="MathJax-Span-3910"><span class="mi" id="MathJax-Span-3911" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3912" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3913" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3914" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.213em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.229em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.771em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-284">z_{\rm true}</script></a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($z_{\rm-fit}-z_{\rm-true}$)-versus-METALLICITY_INDEX-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($z_{\rm-fit}-z_{\rm-true}$)-versus-METALLICITY_INDEX-and-$z_{\rm-true}$-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plots of summary statistics of difference (<span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-285-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;f&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;i&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3915" role="math" style="width: 4.713em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.912em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.989em, 1003.912em, 2.758em, -999.998em); top: -2.498em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3916"><span class="msubsup" id="MathJax-Span-3917"><span style="display: inline-block; position: relative; width: 1.123em; height: 0px;"><span style="position: absolute; clip: rect(3.495em, 1000.386em, 4.2em, -999.998em); top: -4.005em; left: 0.002em;"><span class="mi" id="MathJax-Span-3918" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span><span style="position: absolute; top: -3.845em; left: 0.386em;"><span class="texatom" id="MathJax-Span-3919"><span class="mrow" id="MathJax-Span-3920"><span class="mi" id="MathJax-Span-3921" style="font-size: 70.7%; font-family: STIXMathJax_Main;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.034em;"></span></span><span class="mi" id="MathJax-Span-3922" style="font-size: 70.7%; font-family: STIXMathJax_Main;">i</span><span class="mi" id="MathJax-Span-3923" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span></span></span><span class="mo" id="MathJax-Span-3924" style="font-family: STIXMathJax_Main; padding-left: 0.258em;">−</span><span class="msubsup" id="MathJax-Span-3925" style="padding-left: 0.258em;"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px;"><span style="position: absolute; clip: rect(3.495em, 1000.386em, 4.2em, -999.998em); top: -4.005em; left: 0.002em;"><span class="mi" id="MathJax-Span-3926" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span><span style="position: absolute; top: -3.845em; left: 0.386em;"><span class="texatom" id="MathJax-Span-3927"><span class="mrow" id="MathJax-Span-3928"><span class="mi" id="MathJax-Span-3929" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3930" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3931" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3932" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.502em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.229em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.771em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">f</mi><mi mathvariant="normal">i</mi><mi mathvariant="normal">t</mi></mrow></msub><mo>−</mo><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-285">z_{\rm fit}-z_{\rm true}</script>) versus METALLICITY_INDEX and <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-286-Frame" tabindex="0" data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;t&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;r&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;u&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;e&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3933" role="math" style="width: 1.925em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.604em; height: 0px; font-size: 120%;"><span style="position: absolute; clip: rect(1.7em, 1001.604em, 2.47em, -999.998em); top: -2.21em; left: 0.002em;"><span class="mrow" id="MathJax-Span-3934"><span class="msubsup" id="MathJax-Span-3935"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px;"><span style="position: absolute; clip: rect(3.495em, 1000.386em, 4.2em, -999.998em); top: -4.005em; left: 0.002em;"><span class="mi" id="MathJax-Span-3936" style="font-family: STIXMathJax_Main-italic;">z</span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span><span style="position: absolute; top: -3.845em; left: 0.386em;"><span class="texatom" id="MathJax-Span-3937"><span class="mrow" id="MathJax-Span-3938"><span class="mi" id="MathJax-Span-3939" style="font-size: 70.7%; font-family: STIXMathJax_Main;">t<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3940" style="font-size: 70.7%; font-family: STIXMathJax_Main;">r<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="mi" id="MathJax-Span-3941" style="font-size: 70.7%; font-family: STIXMathJax_Main;">u</span><span class="mi" id="MathJax-Span-3942" style="font-size: 70.7%; font-family: STIXMathJax_Main;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.008em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.213em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.229em; border-left-width: 0px; border-left-style: solid; width: 0px; height: 0.771em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>z</mi><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">t</mi><mi mathvariant="normal">r</mi><mi mathvariant="normal">u</mi><mi mathvariant="normal">e</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-286">z_{\rm true}</script></a></div>

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as mplplot
import astropy.io.fits as astrofits
from IPython.core.display import display
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
data = np.loadtxt('../modelFitResults/regular_zgrid_model_redshift_fits')

# %%
dataSeries = pd.Series(data)

# %%
permutationData = np.loadtxt('/Users/hughdickinson/Documents/Physics/WISPS_Hubble_Constraint/WISPSHubbleConstantConstraint/testModelSpectra/permutations_3')

# %%
permutationDataFrame = pd.DataFrame(permutationData, columns=['METALLICITY_INDEX','AGE', 'TAU','REDSHIFT', 'SIGTONOISE_INDEX'])
display(permutationDataFrame)
# Out:
#       METALLICITY_INDEX    AGE   TAU  REDSHIFT  SIGTONOISE_INDEX
# 0                   1.0  1.000  0.05       1.0               0.0
# 1                   1.0  1.375  0.05       1.0               0.0
# 2                   1.0  1.750  0.05       1.0               0.0
# 3                   1.0  2.125  0.05       1.0               0.0
# 4                   1.0  2.500  0.05       1.0               0.0
# 5                   2.0  1.000  0.05       1.0               0.0
# 6                   2.0  1.375  0.05       1.0               0.0
# 7                   2.0  1.750  0.05       1.0               0.0
# 8                   2.0  2.125  0.05       1.0               0.0
# 9                   2.0  2.500  0.05       1.0               0.0
# 10                  4.0  1.000  0.05       1.0               0.0
# 11                  4.0  1.375  0.05       1.0               0.0
# 12                  4.0  1.750  0.05       1.0               0.0
# ...

# %%
tauValues = np.unique(permutationDataFrame.TAU)
ageValues = np.unique(permutationDataFrame.AGE)
metallicityIndices = np.unique(permutationDataFrame.METALLICITY_INDEX)
redshiftValues = sorted(np.unique(permutationDataFrame.REDSHIFT))
metallicityValues = {0: 0.0001,1: 0.0004, 2: 0.004, 3: 0.008, 4: 0.02, 5: 0.05, 6: 0.1}

print(tauValues, ageValues, metallicityValues, redshiftValues)
# Out:
# [ 0.05  0.1   0.15  0.2 ] [ 1.     1.375  1.75   2.125  2.5  ] {0: 0.0001, 1: 0.0004, 2: 0.004, 3: 0.008, 4: 0.02, 5: 0.05, 6: 0.1} [1.0, 1.0789473684210527, 1.1578947368421053, 1.236842105263158, 1.3157894736842106, 1.3947368421052633, 1.4736842105263157, 1.5526315789473684, 1.631578947368421, 1.7105263157894737, 1.7894736842105263, 1.8684210526315788, 1.9473684210526314, 2.0263157894736841, 2.1052631578947367, 2.1842105263157894, 2.263157894736842, 2.3421052631578947, 2.4210526315789473, 2.5]

# %% [markdown]
# # Initial plot of fit results
# True redshift values are overlaid as vertical red lines.

# %%
dataSeriesAxes = dataSeries.plot.hist(bins=100, histtype='step', fill=True, alpha=0.2)
dataSeriesAxes.vlines(np.unique(permutationDataFrame.REDSHIFT), ymin=dataSeriesAxes.get_ylim()[0], ymax=dataSeriesAxes.get_ylim()[1], colors='r')

# %% [markdown]
# ### Similar plot with restricted reshift range

# %%
dataSeriesAxes = dataSeries.plot.hist(bins=50, histtype='step', fill=True, alpha=0.2, range=(0.9, 2.6))
dataSeriesAxes.vlines(np.unique(permutationDataFrame.REDSHIFT), ymin=dataSeriesAxes.get_ylim()[0], ymax=dataSeriesAxes.get_ylim()[1], colors='r')

# %% [markdown]
# # Compute and plot difference between true and best fit redshift

# %%
permutationSubsetDataFrame = permutationDataFrame.iloc[0:len(dataSeries)].copy()
permutationSubsetDataFrame['BEST_FIT_REDSHIFT'] = dataSeries
permutationSubsetDataFrame['DELTA'] = (permutationSubsetDataFrame.BEST_FIT_REDSHIFT - permutationSubsetDataFrame.REDSHIFT)/(1 + permutationSubsetDataFrame.REDSHIFT)
deltaAxes = permutationSubsetDataFrame.DELTA.plot.hist(bins=100, histtype='step', fill=True, alpha=0.2)
deltaAxes.set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=15)
deltaDataCut = (permutationSubsetDataFrame.DELTA < 0.1) & (permutationSubsetDataFrame.DELTA > 0) & (permutationSubsetDataFrame.AGE > 3.5)
#display(permutationSubsetDataFrame[deltaDataCut])
#print(permutationSubsetDataFrame[deltaDataCut].index)

#display(permutationSubsetDataFrame.iloc[1060])

# %% [markdown]
# # Functions to plot grids of fit results grouped according to input model parameters

# %%
def genGroupedRedshiftFitSubplots(data, groupbyCol, redshifts, groupByColUnit = None):
    grouped = data.groupby(groupbyCol)
    numGroups = grouped.ngroups
    # make subplots with three plots per row and as many rows as required
    numRows = np.ceil(numGroups/3)
    figure, axes = mplplot.subplots(figsize=(9,3*numRows), 
                                    nrows=int(numRows), 
                                    ncols=3)
    for plotIndex, (groupKey, plotAxis) in enumerate(zip(sorted(grouped.groups.keys()), axes.flatten())) :
        grouped.get_group(groupKey).BEST_FIT_REDSHIFT.plot.hist(ax=plotAxis, histtype='step', fill=True, alpha=0.2, bins=50, range=(0, 5))
        plotAxis.set_title('{} = {:4.2f} {}'.format(groupbyCol, groupKey, groupByColUnit if groupByColUnit is not None else ''))
        plotAxis.set_xlabel('Best Fit Redshift')
        plotAxis.vlines(redshifts, ymin=plotAxis.get_ylim()[0], ymax=plotAxis.get_ylim()[1], colors='r')

    mplplot.suptitle(groupbyCol, y=1.01)
    mplplot.tight_layout()
    
def genGroupedRedshiftFitDeltaSubplots(data, groupbyCol, redshifts, groupByColUnit = None):
    grouped = data.groupby(groupbyCol)
    numGroups = grouped.ngroups
    # make subplots with three plots per row and as many rows as required
    numRows = np.ceil(numGroups/3)
    figure, axes = mplplot.subplots(figsize=(9,3*numRows), 
                                    nrows=int(numRows), 
                                    ncols=3)
    for plotIndex, (groupKey, plotAxis) in enumerate(zip(sorted(grouped.groups.keys()), axes.flatten())) :
        grouped.get_group(groupKey).DELTA.plot.hist(ax=plotAxis, histtype='step', fill=True, alpha=0.2, bins=50)
        plotAxis.set_title('{} = {:4.2f} {}'.format(groupbyCol, groupKey, groupByColUnit if groupByColUnit is not None else ''))
        plotAxis.set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=15)
        
    mplplot.suptitle(groupbyCol, y=1.01)
    mplplot.tight_layout()

# %% [markdown]
# # Grouped Plots
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by stellar population AGE

# %%
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "AGE", np.unique(permutationDataFrame.REDSHIFT.values), "Gyr")

# %% [markdown]
# ## Difference ($z_{\rm fit}-z_{\rm true}$) values grouped by stellar population AGE

# %%
genGroupedRedshiftFitDeltaSubplots(permutationSubsetDataFrame, "AGE", np.unique(permutationDataFrame.REDSHIFT.values), "Gyr")

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by starburst duration AGE

# %%
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "TAU", np.unique(permutationDataFrame.REDSHIFT.values), 'Gyr')

# %% [markdown]
# ## Difference ($z_{\rm fit}-z_{\rm true}$) values grouped by starburst duration TAU

# %%
genGroupedRedshiftFitDeltaSubplots(permutationSubsetDataFrame, "TAU", np.unique(permutationDataFrame.REDSHIFT.values), 'Gyr')

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by METALLICITY_INDEX
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "METALLICITY_INDEX", np.unique(permutationDataFrame.REDSHIFT.values))

# %% [markdown]
# ## Difference ($z_{\rm fit}-z_{\rm true}$) values grouped by METALLICITY INDEX
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genGroupedRedshiftFitDeltaSubplots(permutationSubsetDataFrame, "METALLICITY_INDEX", np.unique(permutationDataFrame.REDSHIFT.values))

# %% [markdown]
# # Plots of summary statistics of difference ($z_{\rm fit}-z_{\rm true}$) versus SP AGE and $z_{\rm true}$

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, np.max], ['MEAN', 'MEDIAN', 'MAX'], deltaStatsAxes.flatten())):
    axes = permutationSubsetDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='AGE', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('SP Age (Gyr)')

mplplot.tight_layout()

# %% [markdown]
# # Plots of summary statistics of difference ($z_{\rm fit}-z_{\rm true}$) versus METALLICITY_INDEX and $z_{\rm true}$
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, np.max], ['MEAN', 'MEDIAN', 'MAX'], deltaStatsAxes.flatten())):
    axes = permutationSubsetDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='METALLICITY_INDEX', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('METALLICITY INDEX')

mplplot.tight_layout()

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(8, 4),
                                                   ncols=2,
                                                   nrows=1)

permutationSubsetDataFrame[permutationSubsetDataFrame.DELTA > 0].plot.scatter(ax=deltaStatsAxes[0], x='DELTA', y='BEST_FIT_REDSHIFT', logx=False)
permutationSubsetDataFrame[permutationSubsetDataFrame.DELTA > 0].plot.scatter(ax=deltaStatsAxes[1], x='DELTA', y='REDSHIFT', logx=True)
