# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></div><div class="lev1 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Data</a></div><div class="lev1 toc-item"><a href="#Compute-difference-between-true-and-best-fit-redshift" data-toc-modified-id="Compute-difference-between-true-and-best-fit-redshift-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Compute difference between true and best fit redshift</a></div><div class="lev2 toc-item"><a href="#Examine-model-grid-vertiex-values" data-toc-modified-id="Examine-model-grid-vertiex-values-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Examine model grid vertiex values</a></div><div class="lev1 toc-item"><a href="#Initial-plot-of-fit-results" data-toc-modified-id="Initial-plot-of-fit-results-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Initial plot of fit results</a></div><div class="lev3 toc-item"><a href="#Similar-plot-with-restricted-reshift-range" data-toc-modified-id="Similar-plot-with-restricted-reshift-range-401"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Similar plot with restricted reshift range</a></div><div class="lev1 toc-item"><a href="#Plot-difference-between-true-and-best-fit-redshift" data-toc-modified-id="Plot-difference-between-true-and-best-fit-redshift-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Plot difference between true and best fit redshift</a></div><div class="lev1 toc-item"><a href="#Functions-to-plot-grids-of-fit-results-grouped-according-to-input-model-parameters" data-toc-modified-id="Functions-to-plot-grids-of-fit-results-grouped-according-to-input-model-parameters-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Functions to plot grids of fit results grouped according to input model parameters</a></div><div class="lev1 toc-item"><a href="#Grouped-Plots" data-toc-modified-id="Grouped-Plots-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Grouped Plots</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-stellar-population-AGE" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-stellar-population-AGE-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Best Fit <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-318"><span class="MJXp-msubsup" id="MJXp-Span-319"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-320" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-321" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-322">f</span><span class="MJXp-mi" id="MJXp-Span-323">i</span><span class="MJXp-mi" id="MJXp-Span-324">t</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-24-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-24">z_{\rm fit}</script> with all true <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-325"><span class="MJXp-msubsup" id="MJXp-Span-326"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-327" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-328" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-329">t</span><span class="MJXp-mi" id="MJXp-Span-330">r</span><span class="MJXp-mi" id="MJXp-Span-331">u</span><span class="MJXp-mi" id="MJXp-Span-332">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-25-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-25">z_{\rm true}</script> values overlaid grouped by stellar population AGE</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-stellar-population-AGE" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-stellar-population-AGE-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-333"><span class="MJXp-mfrac" id="MJXp-Span-334" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-335"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-336" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-337" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-338">f</span><span class="MJXp-mi" id="MJXp-Span-339">i</span><span class="MJXp-mi" id="MJXp-Span-340">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-341">−</span><span class="MJXp-msubsup" id="MJXp-Span-342"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-343" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-344" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-345">t</span><span class="MJXp-mi" id="MJXp-Span-346">r</span><span class="MJXp-mi" id="MJXp-Span-347">u</span><span class="MJXp-mi" id="MJXp-Span-348">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-349">1</span><span class="MJXp-mo" id="MJXp-Span-350">+</span><span class="MJXp-msubsup" id="MJXp-Span-351"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-352" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-353" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-354">t</span><span class="MJXp-mi" id="MJXp-Span-355">r</span><span class="MJXp-mi" id="MJXp-Span-356">u</span><span class="MJXp-mi" id="MJXp-Span-357">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-26-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-26">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) values grouped by stellar population AGE</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-starburst-duration-TAU" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-starburst-duration-TAU-73"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Best Fit <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-358"><span class="MJXp-msubsup" id="MJXp-Span-359"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-360" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-361" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-362">f</span><span class="MJXp-mi" id="MJXp-Span-363">i</span><span class="MJXp-mi" id="MJXp-Span-364">t</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-27-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-27">z_{\rm fit}</script> with all true <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-365"><span class="MJXp-msubsup" id="MJXp-Span-366"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-367" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-368" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-369">t</span><span class="MJXp-mi" id="MJXp-Span-370">r</span><span class="MJXp-mi" id="MJXp-Span-371">u</span><span class="MJXp-mi" id="MJXp-Span-372">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-28-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-28">z_{\rm true}</script> values overlaid grouped by starburst duration TAU</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-starburst-duration-TAU" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-starburst-duration-TAU-74"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-373"><span class="MJXp-mfrac" id="MJXp-Span-374" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-375"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-376" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-377" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-378">f</span><span class="MJXp-mi" id="MJXp-Span-379">i</span><span class="MJXp-mi" id="MJXp-Span-380">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-381">−</span><span class="MJXp-msubsup" id="MJXp-Span-382"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-383" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-384" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-385">t</span><span class="MJXp-mi" id="MJXp-Span-386">r</span><span class="MJXp-mi" id="MJXp-Span-387">u</span><span class="MJXp-mi" id="MJXp-Span-388">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-389">1</span><span class="MJXp-mo" id="MJXp-Span-390">+</span><span class="MJXp-msubsup" id="MJXp-Span-391"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-392" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-393" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-394">t</span><span class="MJXp-mi" id="MJXp-Span-395">r</span><span class="MJXp-mi" id="MJXp-Span-396">u</span><span class="MJXp-mi" id="MJXp-Span-397">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-29-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-29">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) values grouped by starburst duration TAU</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-METALLICITY_INDEX" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-METALLICITY_INDEX-75"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Best Fit <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-398"><span class="MJXp-msubsup" id="MJXp-Span-399"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-400" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-401" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-402">f</span><span class="MJXp-mi" id="MJXp-Span-403">i</span><span class="MJXp-mi" id="MJXp-Span-404">t</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-30-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-30">z_{\rm fit}</script> with all true <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-405"><span class="MJXp-msubsup" id="MJXp-Span-406"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-407" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-408" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-409">t</span><span class="MJXp-mi" id="MJXp-Span-410">r</span><span class="MJXp-mi" id="MJXp-Span-411">u</span><span class="MJXp-mi" id="MJXp-Span-412">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-31-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-31">z_{\rm true}</script> values overlaid grouped by METALLICITY_INDEX</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-METALLICITY-INDEX" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-METALLICITY-INDEX-76"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-446"><span class="MJXp-mfrac" id="MJXp-Span-447" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-448"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-449" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-450" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-451">f</span><span class="MJXp-mi" id="MJXp-Span-452">i</span><span class="MJXp-mi" id="MJXp-Span-453">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-454">−</span><span class="MJXp-msubsup" id="MJXp-Span-455"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-456" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-457" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-458">t</span><span class="MJXp-mi" id="MJXp-Span-459">r</span><span class="MJXp-mi" id="MJXp-Span-460">u</span><span class="MJXp-mi" id="MJXp-Span-461">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-462">1</span><span class="MJXp-mo" id="MJXp-Span-463">+</span><span class="MJXp-msubsup" id="MJXp-Span-464"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-465" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-466" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-467">t</span><span class="MJXp-mi" id="MJXp-Span-468">r</span><span class="MJXp-mi" id="MJXp-Span-469">u</span><span class="MJXp-mi" id="MJXp-Span-470">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-34-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-34">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) values grouped by METALLICITY INDEX</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-SIGTONOISE_INDEX" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-SIGTONOISE_INDEX-77"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Best Fit <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-504"><span class="MJXp-msubsup" id="MJXp-Span-505"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-506" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-507" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-508">f</span><span class="MJXp-mi" id="MJXp-Span-509">i</span><span class="MJXp-mi" id="MJXp-Span-510">t</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-37-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-37">z_{\rm fit}</script> with all true <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-511"><span class="MJXp-msubsup" id="MJXp-Span-512"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-513" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-514" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-515">t</span><span class="MJXp-mi" id="MJXp-Span-516">r</span><span class="MJXp-mi" id="MJXp-Span-517">u</span><span class="MJXp-mi" id="MJXp-Span-518">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-38-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-38">z_{\rm true}</script> values overlaid grouped by SIGTONOISE_INDEX</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-SIGTONOISE_INDEX" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-SIGTONOISE_INDEX-78"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>Difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-539"><span class="MJXp-mfrac" id="MJXp-Span-540" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-541"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-542" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-543" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-544">f</span><span class="MJXp-mi" id="MJXp-Span-545">i</span><span class="MJXp-mi" id="MJXp-Span-546">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-547">−</span><span class="MJXp-msubsup" id="MJXp-Span-548"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-549" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-550" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-551">t</span><span class="MJXp-mi" id="MJXp-Span-552">r</span><span class="MJXp-mi" id="MJXp-Span-553">u</span><span class="MJXp-mi" id="MJXp-Span-554">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-555">1</span><span class="MJXp-mo" id="MJXp-Span-556">+</span><span class="MJXp-msubsup" id="MJXp-Span-557"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-558" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-559" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-560">t</span><span class="MJXp-mi" id="MJXp-Span-561">r</span><span class="MJXp-mi" id="MJXp-Span-562">u</span><span class="MJXp-mi" id="MJXp-Span-563">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-40-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-40">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) values grouped by SIGTONOISE_INDEX</a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SP-AGE-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SP-AGE-and-$z_{\rm-true}$-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plots of summary statistics of difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-584"><span class="MJXp-mfrac" id="MJXp-Span-585" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-586"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-587" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-588" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-589">f</span><span class="MJXp-mi" id="MJXp-Span-590">i</span><span class="MJXp-mi" id="MJXp-Span-591">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-592">−</span><span class="MJXp-msubsup" id="MJXp-Span-593"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-594" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-595" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-596">t</span><span class="MJXp-mi" id="MJXp-Span-597">r</span><span class="MJXp-mi" id="MJXp-Span-598">u</span><span class="MJXp-mi" id="MJXp-Span-599">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-600">1</span><span class="MJXp-mo" id="MJXp-Span-601">+</span><span class="MJXp-msubsup" id="MJXp-Span-602"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-603" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-604" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-605">t</span><span class="MJXp-mi" id="MJXp-Span-606">r</span><span class="MJXp-mi" id="MJXp-Span-607">u</span><span class="MJXp-mi" id="MJXp-Span-608">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-42-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-42">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) versus SP AGE and <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-609"><span class="MJXp-msubsup" id="MJXp-Span-610"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-611" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-612" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-613">t</span><span class="MJXp-mi" id="MJXp-Span-614">r</span><span class="MJXp-mi" id="MJXp-Span-615">u</span><span class="MJXp-mi" id="MJXp-Span-616">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-43-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-43">z_{\rm true}</script></a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-METALLICITY_INDEX-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-METALLICITY_INDEX-and-$z_{\rm-true}$-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Plots of summary statistics of difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-617"><span class="MJXp-mfrac" id="MJXp-Span-618" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-619"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-620" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-621" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-622">f</span><span class="MJXp-mi" id="MJXp-Span-623">i</span><span class="MJXp-mi" id="MJXp-Span-624">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-625">−</span><span class="MJXp-msubsup" id="MJXp-Span-626"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-627" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-628" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-629">t</span><span class="MJXp-mi" id="MJXp-Span-630">r</span><span class="MJXp-mi" id="MJXp-Span-631">u</span><span class="MJXp-mi" id="MJXp-Span-632">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-633">1</span><span class="MJXp-mo" id="MJXp-Span-634">+</span><span class="MJXp-msubsup" id="MJXp-Span-635"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-636" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-637" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-638">t</span><span class="MJXp-mi" id="MJXp-Span-639">r</span><span class="MJXp-mi" id="MJXp-Span-640">u</span><span class="MJXp-mi" id="MJXp-Span-641">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-44-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-44">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) versus METALLICITY_INDEX and <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-642"><span class="MJXp-msubsup" id="MJXp-Span-643"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-644" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-645" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-646">t</span><span class="MJXp-mi" id="MJXp-Span-647">r</span><span class="MJXp-mi" id="MJXp-Span-648">u</span><span class="MJXp-mi" id="MJXp-Span-649">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-45-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-45">z_{\rm true}</script></a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SIGTONOISE_INDEX-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SIGTONOISE_INDEX-and-$z_{\rm-true}$-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Plots of summary statistics of difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-683"><span class="MJXp-mfrac" id="MJXp-Span-684" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-685"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-686" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-687" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-688">f</span><span class="MJXp-mi" id="MJXp-Span-689">i</span><span class="MJXp-mi" id="MJXp-Span-690">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-691">−</span><span class="MJXp-msubsup" id="MJXp-Span-692"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-693" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-694" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-695">t</span><span class="MJXp-mi" id="MJXp-Span-696">r</span><span class="MJXp-mi" id="MJXp-Span-697">u</span><span class="MJXp-mi" id="MJXp-Span-698">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-699">1</span><span class="MJXp-mo" id="MJXp-Span-700">+</span><span class="MJXp-msubsup" id="MJXp-Span-701"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-702" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-703" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-704">t</span><span class="MJXp-mi" id="MJXp-Span-705">r</span><span class="MJXp-mi" id="MJXp-Span-706">u</span><span class="MJXp-mi" id="MJXp-Span-707">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-48-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-48">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) versus SIGTONOISE_INDEX and <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-708"><span class="MJXp-msubsup" id="MJXp-Span-709"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-710" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-711" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-712">t</span><span class="MJXp-mi" id="MJXp-Span-713">r</span><span class="MJXp-mi" id="MJXp-Span-714">u</span><span class="MJXp-mi" id="MJXp-Span-715">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-49-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-49">z_{\rm true}</script></a></div><div class="lev3 toc-item"><a href="#Note-on-MEDIAN-statistic" data-toc-modified-id="Note-on-MEDIAN-statistic-1001"><span class="toc-item-num">10.0.1&nbsp;&nbsp;</span>Note on MEDIAN statistic</a></div><div class="lev1 toc-item"><a href="#Categorized-plots-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-$z_{\rm-true}$-and-$z_{\rm-true}$" data-toc-modified-id="Categorized-plots-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-$z_{\rm-true}$-and-$z_{\rm-true}$-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Categorized plots of difference (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-736"><span class="MJXp-mfrac" id="MJXp-Span-737" style="vertical-align: 0.25em;"><span class="MJXp-box MJXp-script"><span class="MJXp-msubsup" id="MJXp-Span-738"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-739" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-740" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-741">f</span><span class="MJXp-mi" id="MJXp-Span-742">i</span><span class="MJXp-mi" id="MJXp-Span-743">t</span></span></span><span class="MJXp-mo" id="MJXp-Span-744">−</span><span class="MJXp-msubsup" id="MJXp-Span-745"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-746" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-747" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-748">t</span><span class="MJXp-mi" id="MJXp-Span-749">r</span><span class="MJXp-mi" id="MJXp-Span-750">u</span><span class="MJXp-mi" id="MJXp-Span-751">e</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span><span class="MJXp-rule" style="height: 1em; border-top-style: none; border-bottom-width: 1px; border-bottom-style: solid; margin: 0.1em 0px;"></span></span><span><span class="MJXp-box MJXp-script"><span class="MJXp-mn" id="MJXp-Span-752">1</span><span class="MJXp-mo" id="MJXp-Span-753">+</span><span class="MJXp-msubsup" id="MJXp-Span-754"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-755" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-756" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-757">t</span><span class="MJXp-mi" id="MJXp-Span-758">r</span><span class="MJXp-mi" id="MJXp-Span-759">u</span><span class="MJXp-mi" id="MJXp-Span-760">e</span></span></span></span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-51-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-51">\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}</script>) versus <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-761"><span class="MJXp-msubsup" id="MJXp-Span-762"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-763" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-764" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-765">t</span><span class="MJXp-mi" id="MJXp-Span-766">r</span><span class="MJXp-mi" id="MJXp-Span-767">u</span><span class="MJXp-mi" id="MJXp-Span-768">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-52-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-52">z_{\rm true}</script> and <span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-769"><span class="MJXp-msubsup" id="MJXp-Span-770"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-771" style="margin-right: 0.05em;">z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-772" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-773">t</span><span class="MJXp-mi" id="MJXp-Span-774">r</span><span class="MJXp-mi" id="MJXp-Span-775">u</span><span class="MJXp-mi" id="MJXp-Span-776">e</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-53-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-53">z_{\rm true}</script></a></div><div class="lev2 toc-item"><a href="#SIGTONOISE_INDEX-($i_{\rm-SN}$)" data-toc-modified-id="SIGTONOISE_INDEX-($i_{\rm-SN}$)-111"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>SIGTONOISE_INDEX (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-777"><span class="MJXp-msubsup" id="MJXp-Span-778"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-779" style="margin-right: 0.05em;">i</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-780" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-781">S</span><span class="MJXp-mi" id="MJXp-Span-782">N</span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-54-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-54">i_{\rm SN}</script>)</a></div><div class="lev2 toc-item"><a href="#METALLICITY_INDEX-($i_{\rm-Z/Z_{\odot}}$)" data-toc-modified-id="METALLICITY_INDEX-($i_{\rm-Z/Z_{\odot}}$)-112"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>METALLICITY_INDEX (<span class="MathJax_Preview" style="color: inherit;"><span class="MJXp-math" id="MJXp-Span-803"><span class="MJXp-msubsup" id="MJXp-Span-804"><span class="MJXp-mi MJXp-italic" id="MJXp-Span-805" style="margin-right: 0.05em;">i</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-806" style="vertical-align: -0.4em;"><span class="MJXp-mi" id="MJXp-Span-807">Z</span><span class="MJXp-mrow" id="MJXp-Span-808"><span class="MJXp-mo" id="MJXp-Span-809">/</span></span><span class="MJXp-msubsup" id="MJXp-Span-810"><span class="MJXp-mi" id="MJXp-Span-811" style="margin-right: 0.05em;">Z</span><span class="MJXp-mrow MJXp-script" id="MJXp-Span-812" style="vertical-align: -0.4em;"><span class="MJXp-mo" id="MJXp-Span-813">⊙</span></span></span></span></span></span></span><span class="MathJax MathJax_Processing" id="MathJax-Element-56-Frame" tabindex="0"></span><script type="math/tex" id="MathJax-Element-56">i_{\rm Z/Z_{\odot}}</script>)</a></div><div class="lev1 toc-item"><a href="#Compute-contamination-fraction" data-toc-modified-id="Compute-contamination-fraction-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Compute contamination fraction</a></div><div class="lev1 toc-item"><a href="#Compute-loss-fraction" data-toc-modified-id="Compute-loss-fraction-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Compute loss fraction</a></div>

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as mplplot
import astropy.io.fits as astrofits
from IPython.core.display import display
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
redshiftFitsFiles = {'ROI' : '../modelFitResults/regular_zgrid_model_redshift_fits', 
                     'CONTAM' : '../modelFitResults/regular_zgrid_model_redshift_fits_contam' }
dataROI = np.loadtxt(redshiftFitsFiles['ROI'])
dataContam = np.loadtxt(redshiftFitsFiles['CONTAM'])

# %%
dataSeries = pd.Series(np.concatenate([dataROI, dataContam]))
dataSeriesROI = pd.Series(dataROI)
dataSeriesContam = pd.Series(dataContam)

# %%
permutationFiles = {'ROI' : '../modelFitResults/regular_zgrid_model_data/permutations_3', 
                    'CONTAM' : '../modelFitResults/regular_zgrid_model_data_contam/permutations_4'}
permutationDataROI = np.loadtxt(permutationFiles['ROI'])
permutationDataContam = np.loadtxt(permutationFiles['CONTAM'])

# %%
permutationDataFrameROI = pd.DataFrame(permutationDataROI, columns=['METALLICITY_INDEX','AGE', 'TAU','REDSHIFT', 'SIGTONOISE_INDEX'])
permutationDataFrameROI['ROI'] = True
permutationDataFrameROI['BEST_FIT_REDSHIFT'] = dataSeriesROI
permutationDataFrameContam = pd.DataFrame(permutationDataContam, columns=['METALLICITY_INDEX','AGE', 'TAU','REDSHIFT', 'SIGTONOISE_INDEX'])
permutationDataFrameContam['ROI'] = False
permutationDataFrameContam['BEST_FIT_REDSHIFT'] = dataSeriesContam

# %% [markdown]
# # Compute difference between true and best fit redshift

# %%
permutationDataFrameROI['DELTA'] = (permutationDataFrameROI.BEST_FIT_REDSHIFT - permutationDataFrameROI.REDSHIFT)/(1 + permutationDataFrameROI.REDSHIFT)
permutationDataFrameContam['DELTA'] = (permutationDataFrameContam.BEST_FIT_REDSHIFT - permutationDataFrameContam.REDSHIFT)/(1 + permutationDataFrameContam.REDSHIFT)

permutationDataFrame = pd.concat([permutationDataFrameROI, permutationDataFrameContam])

# %% [markdown]
# ## Examine model grid vertiex values

# %%
tauValues = np.unique(permutationDataFrame.TAU)
ageValues = np.unique(permutationDataFrame.AGE)
metallicityIndices = np.unique(permutationDataFrame.METALLICITY_INDEX)
redshiftValues = sorted(np.unique(permutationDataFrame.REDSHIFT))
metallicityValues = {0: 0.0001,1: 0.0004, 2: 0.004, 3: 0.008, 4: 0.02, 5: 0.05, 6: 0.1}
sigToNoiseValues = {0 : 2.0, 1: 3.0, 2: 4.0, 3: 5.0, 4: 6.0}
redshiftValuesROI = sorted(np.unique(permutationDataFrameROI.REDSHIFT))
redshiftValuesContam = sorted(np.unique(permutationDataFrameContam.REDSHIFT))

splitRedshiftValues = [redshiftValuesROI, redshiftValuesContam]

print(tauValues, 
      ageValues, 
      metallicityValues, 
      redshiftValues, 
      redshiftValuesROI,
      redshiftValuesContam,
      sigToNoiseValues)

redshiftRange = (np.amin(redshiftValues), np.amax(redshiftValues))
roiRedshiftRange = (np.amin(redshiftValuesROI), np.amax(redshiftValuesROI))
contamRedshiftRange = (np.amin(redshiftValuesContam), np.amax(redshiftValuesContam))
redshiftIsInROI = lambda z : np.logical_and(z > roiRedshiftRange[0], z < roiRedshiftRange[1])

redshiftSubsetColours = { 'ROI' : 'r', 'CONTAM' : 'b', 'FULL' : 'g' }
# Out:
# [ 0.05  0.1   0.15  0.2 ] [ 1.     1.375  1.75   2.125  2.5  ] {0: 0.0001, 1: 0.0004, 2: 0.004, 3: 0.008, 4: 0.02, 5: 0.05, 6: 0.1} [0.074999999999999997, 0.14999999999999999, 0.22499999999999998, 0.29999999999999999, 0.375, 0.45000000000000001, 0.52499999999999991, 0.59999999999999998, 0.67499999999999993, 0.74999999999999989, 0.82499999999999996, 0.89999999999999991, 0.97499999999999987, 1.0, 1.0789473684210527, 1.1578947368421053, 1.236842105263158, 1.3157894736842106, 1.3947368421052633, 1.4736842105263157, 1.5526315789473684, 1.631578947368421, 1.7105263157894737, 1.7894736842105263, 1.8684210526315788, 1.9473684210526314, 2.0263157894736841, 2.1052631578947367, 2.1842105263157894, 2.263157894736842, 2.3421052631578947, 2.4210526315789473, 2.5, 2.5750000000000002, 2.6500000000000004, 2.7250000000000005, 2.8000000000000007, 2.8750000000000009, 2.9500000000000011] [1.0, 1.0789473684210527, 1.1578947368421053, 1.236842105263158, 1.3157894736842106, 1.3947368421052633, 1.47368421052
# ...

# %% [markdown]
# # Initial plot of fit results
# True redshift values are overlaid as vertical red lines.

# %%
dataSeriesAxes = permutationDataFrameROI.BEST_FIT_REDSHIFT.plot.hist(bins=100, histtype='step', fill=True, ec=redshiftSubsetColours['ROI'], fc=redshiftSubsetColours['ROI'], alpha=0.3, range=(0,5), label='ROI')
dataSeriesAxes = permutationDataFrameContam.BEST_FIT_REDSHIFT.plot.hist(bins=100, histtype='step', fill=True, ec=redshiftSubsetColours['CONTAM'], fc=redshiftSubsetColours['CONTAM'], alpha=0.3, range=(0,5), label='CONTAM')
vlinesYmin, vlinesYmax = dataSeriesAxes.get_ylim()[0], dataSeriesAxes.get_ylim()[1]
dataSeriesAxes.vlines(np.unique(permutationDataFrameROI.REDSHIFT), ymin=vlinesYmin, ymax=vlinesYmax, colors=redshiftSubsetColours['ROI'], alpha=0.1)
dataSeriesAxes.vlines(np.unique(permutationDataFrameContam.REDSHIFT), ymin=vlinesYmin, ymax=vlinesYmax, colors=redshiftSubsetColours['CONTAM'], alpha=0.1)
dataSeriesAxes.legend()

# %% [markdown]
# ### Similar plot with restricted reshift range

# %%
dataSeriesAxes = permutationDataFrameROI.BEST_FIT_REDSHIFT.plot.hist(bins=100, histtype='step', fill=True, ec=redshiftSubsetColours['ROI'], fc=redshiftSubsetColours['ROI'], alpha=0.3, range=(0.9,2.6), label='ROI')
dataSeriesAxes = permutationDataFrameContam.BEST_FIT_REDSHIFT.plot.hist(bins=100, histtype='step', fill=True, ec=redshiftSubsetColours['CONTAM'], fc=redshiftSubsetColours['CONTAM'], alpha=0.3, range=(0.9,2.6), label='CONTAM')
vlinesYmin, vlinesYmax = dataSeriesAxes.get_ylim()[0], dataSeriesAxes.get_ylim()[1]
dataSeriesAxes.vlines(np.unique(permutationDataFrameROI.REDSHIFT), ymin=vlinesYmin, ymax=vlinesYmax, colors=redshiftSubsetColours['ROI'], alpha=0.1)
dataSeriesAxes.vlines(np.unique(permutationDataFrameContam.REDSHIFT), ymin=vlinesYmin, ymax=vlinesYmax, colors=redshiftSubsetColours['CONTAM'], alpha=0.1)
dataSeriesAxes.legend()

# %% [markdown]
# # Plot difference between true and best fit redshift

# %%
deltaAxes = permutationDataFrameROI.DELTA.plot.hist(bins=100, histtype='step', fill=True, ec=redshiftSubsetColours['ROI'], fc=redshiftSubsetColours['ROI'], alpha=0.3, logy=True, label='ROI')
deltaAxes = permutationDataFrameContam.DELTA.plot.hist(ax=deltaAxes, bins=100, histtype='step', fill=True, ec=redshiftSubsetColours['CONTAM'], fc=redshiftSubsetColours['CONTAM'], alpha=0.3, logy=True, label='CONTAM')
deltaAxes.set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=15)
deltaAxes.legend()

# %% [markdown]
# # Functions to plot grids of fit results grouped according to input model parameters

# %%
def genGroupedRedshiftFitSubplots(data, groupbyCol, redshifts, groupByColUnit = None, restrictToModelledRedshifts = False):
    redshiftRange = (0, 5) if not restrictToModelledRedshifts else (np.amin(np.unique(np.concatenate(redshifts))) - 0.1, np.amax(np.unique(np.concatenate(redshifts)))+0.1)
    supTitlePrefix = '' if not restrictToModelledRedshifts else 'Redshift range restricted to modelled values. '
    grouped = data.groupby(groupbyCol)
    numGroups = grouped.ngroups
    # make subplots with three plots per row and as many rows as required
    numRows = np.ceil(numGroups/3)
    figure, axes = mplplot.subplots(figsize=(9,3*numRows), 
                                    nrows=int(numRows), 
                                    ncols=3)
    for plotIndex, (groupKey, plotAxis) in enumerate(zip(sorted(grouped.groups.keys()), axes.flatten())) :
        groupData = grouped.get_group(groupKey)
        groupData[groupData.ROI].BEST_FIT_REDSHIFT.plot.hist(ax=plotAxis, histtype='step', fill=True, ec=redshiftSubsetColours['ROI'], fc=redshiftSubsetColours['ROI'], alpha=0.3, bins=50, range=redshiftRange, label='ROI')
        groupData[~groupData.ROI].BEST_FIT_REDSHIFT.plot.hist(ax=plotAxis, histtype='step', fill=True, ec=redshiftSubsetColours['CONTAM'], fc=redshiftSubsetColours['CONTAM'], alpha=0.3, bins=50, range=redshiftRange, label='CONTAM')
        plotAxis.set_title('{} = {:4.2f} {}'.format(groupbyCol, groupKey, groupByColUnit if groupByColUnit is not None else ''))
        plotAxis.set_xlabel('Best Fit Redshift')
        vlinesYmin, vlinesYmax = plotAxis.get_ylim()[0], plotAxis.get_ylim()[1]
        for redshiftSubset, colour in zip(redshifts, [redshiftSubsetColours['ROI'], redshiftSubsetColours['CONTAM']]) :
            plotAxis.vlines(redshiftSubset, ymin=vlinesYmin, ymax=vlinesYmax, colors=colour, alpha=0.1)
        plotAxis.legend()
            
    mplplot.suptitle(supTitlePrefix + groupbyCol, y=1.01)
    mplplot.tight_layout()
    
def genGroupedRedshiftFitDeltaSubplots(data, groupbyCol, redshifts, groupByColUnit = None):
    grouped = data.groupby(groupbyCol)
    numGroups = grouped.ngroups
    # make subplots with three plots per row and as many rows as required
    numRows = np.ceil(numGroups/3)
    figure, axes = mplplot.subplots(figsize=(9,3*numRows), 
                                    nrows=int(numRows), 
                                    ncols=3)
    for plotIndex, (groupKey, plotAxis) in enumerate(zip(sorted(grouped.groups.keys()), axes.flatten())) :
        groupData = grouped.get_group(groupKey)
        groupData[groupData['ROI']].DELTA.plot.hist(ax=plotAxis, histtype='step', fill=True, ec=redshiftSubsetColours['ROI'], fc=redshiftSubsetColours['ROI'], alpha=0.3, bins=50, label='ROI')
        groupData[np.logical_not(groupData['ROI'])].DELTA.plot.hist(ax=plotAxis, histtype='step', fill=True, ec=redshiftSubsetColours['CONTAM'], fc=redshiftSubsetColours['CONTAM'], alpha=0.3, bins=50, label='CONTAM')
        plotAxis.set_title('{} = {:4.2f} {}'.format(groupbyCol, groupKey, groupByColUnit if groupByColUnit is not None else ''))
        plotAxis.set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=15)
        plotAxis.legend()
        
    mplplot.suptitle(groupbyCol, y=1.01)
    mplplot.tight_layout()

# %% [markdown]
# # Grouped Plots
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by stellar population AGE

# %%
genGroupedRedshiftFitSubplots(permutationDataFrame, "AGE", splitRedshiftValues, "Gyr")
genGroupedRedshiftFitSubplots(permutationDataFrame, "AGE", splitRedshiftValues, "Gyr", restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by stellar population AGE

# %%
genGroupedRedshiftFitDeltaSubplots(permutationDataFrame, "AGE", splitRedshiftValues, "Gyr")

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by starburst duration TAU

# %%
genGroupedRedshiftFitSubplots(permutationDataFrame, "TAU", splitRedshiftValues, 'Gyr')
genGroupedRedshiftFitSubplots(permutationDataFrame, "TAU", splitRedshiftValues, 'Gyr', restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by starburst duration TAU

# %%
genGroupedRedshiftFitDeltaSubplots(permutationDataFrame, "TAU", splitRedshiftValues, 'Gyr')

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by METALLICITY_INDEX
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genGroupedRedshiftFitSubplots(permutationDataFrame, "METALLICITY_INDEX", splitRedshiftValues)
genGroupedRedshiftFitSubplots(permutationDataFrame, "METALLICITY_INDEX", splitRedshiftValues, restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by METALLICITY INDEX
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genGroupedRedshiftFitDeltaSubplots(permutationDataFrame, "METALLICITY_INDEX", splitRedshiftValues)

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by SIGTONOISE_INDEX
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$

# %%
genGroupedRedshiftFitSubplots(permutationDataFrame, "SIGTONOISE_INDEX", splitRedshiftValues)
genGroupedRedshiftFitSubplots(permutationDataFrame, "SIGTONOISE_INDEX", splitRedshiftValues, restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by SIGTONOISE_INDEX
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$

# %%
genGroupedRedshiftFitDeltaSubplots(permutationDataFrame, "SIGTONOISE_INDEX", splitRedshiftValues)

# %% [markdown]
# # Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus SP AGE and $z_{\rm true}$

# %%
absmax = lambda x : np.max(np.abs(x))

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, absmax], ['MEAN', 'MEDIAN', 'ABSMAX'], deltaStatsAxes.flatten())):
    axes = permutationDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='AGE', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('SP Age (Gyr)')

mplplot.tight_layout()

# %% [markdown]
# # Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus METALLICITY_INDEX and $z_{\rm true}$
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, absmax], ['MEAN', 'MEDIAN', 'ABSMAX'], deltaStatsAxes.flatten())):
    axes = permutationDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='METALLICITY_INDEX', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('METALLICITY INDEX')

mplplot.tight_layout()

# %% [markdown]
# # Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus SIGTONOISE_INDEX and $z_{\rm true}$
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$
#
# ### Note on MEDIAN statistic
# For the lowest signal-to-noise level the median `DELTA` is close to zero for all true redshift values. This is likely due to a markedly increased number of fitted redshifts that are higher than the true value for this S/N level.

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, absmax], ['MEAN', 'MEDIAN', 'ABSMAX'], deltaStatsAxes.flatten())):
    axes = permutationDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='SIGTONOISE_INDEX', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('SIGTONOISE INDEX')

mplplot.tight_layout()

# %% [markdown]
# # Categorized plots of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus $z_{\rm true}$ and $z_{\rm true}$

# %%
def genCategorizedZVersusDeltaPlots(data, categoryColumn, categoryLabelFunctor, colorMapName = 'viridis') :
    figure, axes = mplplot.subplots(figsize=(16, 8),
                                    ncols=2,
                                    nrows=1)

    groupedData = data.groupby(categoryColumn)
    colourMap = matplotlib.cm.get_cmap(colorMapName)
    indices = np.unique(data[categoryColumn].values)
    minIndex, maxIndex = np.amax(indices), np.amin(indices)
    groupColours = {int(index) : colourMap((index-minIndex)/(maxIndex - minIndex)) for index in indices} 

    for key, group in groupedData:
        group.plot.scatter(ax=axes[0], x='DELTA', y='BEST_FIT_REDSHIFT', logx=False, label=categoryLabelFunctor(key), s=20, color=groupColours[int(key)])
        group.plot.scatter(ax=axes[1], x='DELTA', y='REDSHIFT', logx=False, label=categoryLabelFunctor(key), s=20, color=groupColours[int(key)])

    deltaStatsAxes[0].set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=20)    
    deltaStatsAxes[1].set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=20) 

    deltaStatsAxes[0].set_ylabel(r'$z_{\rm fit}$', size=20)    
    deltaStatsAxes[1].set_ylabel(r'$z_{\rm true}$', size=20)  
    
    mplplot.tight_layout()
    return deltaStatsAxes

# %% [markdown]
# ## SIGTONOISE_INDEX ($i_{\rm SN}$)
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$

# %%
deltaStatsAxes = genCategorizedZVersusDeltaPlots(permutationDataFrame, 'SIGTONOISE_INDEX', lambda key : '$i_{} = ${}'.format(r'{\rm SN}',int(key)))

# %%
deltaStatsAxes[0].axhline
# Out:
# <bound method Axes.axhline of <matplotlib.axes._subplots.AxesSubplot object at 0x111951d30>>

# %% [markdown]
# ## METALLICITY_INDEX ($i_{\rm Z/Z_{\odot}}$)
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genCategorizedZVersusDeltaPlots(permutationDataFrame, 'METALLICITY_INDEX', lambda key : '$i_{} = ${}'.format(r'{\rm Z/Z_{\odot}}',int(key)))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x111951d30>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x111f08358>], dtype=object)

# %% [markdown]
# # Compute contamination fraction
# This is the fraction of spectra with true (modelled) redshifts outside of the ROI that have best-fiiting redshifts that fall within the ROI.

# %%
numContamInROI = len(permutationDataFrameContam[redshiftIsInROI(permutationDataFrameContam.BEST_FIT_REDSHIFT)].index)
numContam = len(permutationDataFrameContam.index)
contamFraction = numContamInROI/numContam
# normalize by the relative extents of the contamination region and the ROI
roiExtent = roiRedshiftRange[1] - roiRedshiftRange[0]
contamExtent = (contamRedshiftRange[1] - contamRedshiftRange[0]) - roiExtent
contamExtentFraction = contamExtent/roiExtent

normContamFraction = contamFraction/contamExtentFraction

print (numContamInROI, numContam, contamFraction, roiExtent, contamExtent, contamExtentFraction, normContamFraction)
# Out:
# 814 5700 0.14280701754385966 1.5 1.375 0.916666666667 0.155789473684

# %% [markdown]
# # Compute loss fraction
# This is the fraction of spectra with true (modelled) redshifts *inside* of the ROI that have best-fitting redshifts that fall *outside* the ROI.

# %%
numInROI = len(permutationDataFrameROI[redshiftIsInROI(permutationDataFrameROI.BEST_FIT_REDSHIFT)].index)
numOutsideROI = len(permutationDataFrameROI.index) - numInROI
lossFraction = numOutsideROI/(numInROI + numOutsideROI)
# normalize by the relative extents of the contamination region and the ROI
roiExtent = roiRedshiftRange[1] - roiRedshiftRange[0]
nonRoiExtent = (redshiftRange[1] - redshiftRange[0]) - (contamRedshiftRange[1] - contamRedshiftRange[0]) + roiExtent
lossExtentFraction = nonRoiExtent/roiExtent

normLossFraction = lossFraction/lossExtentFraction

print (numInROI, numOutsideROI, lossFraction, roiExtent, nonRoiExtent, lossExtentFraction, normLossFraction)
# Out:
# 4916 1084 0.18066666666666667 1.5 1.5 1.0 0.180666666667
