# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></div><div class="lev1 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Data</a></div><div class="lev1 toc-item"><a href="#Initial-plot-of-fit-results" data-toc-modified-id="Initial-plot-of-fit-results-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Initial plot of fit results</a></div><div class="lev3 toc-item"><a href="#Similar-plot-with-restricted-reshift-range" data-toc-modified-id="Similar-plot-with-restricted-reshift-range-301"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Similar plot with restricted reshift range</a></div><div class="lev1 toc-item"><a href="#Compute-and-plot-difference-between-true-and-best-fit-redshift" data-toc-modified-id="Compute-and-plot-difference-between-true-and-best-fit-redshift-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Compute and plot difference between true and best fit redshift</a></div><div class="lev1 toc-item"><a href="#Functions-to-plot-grids-of-fit-results-grouped-according-to-input-model-parameters" data-toc-modified-id="Functions-to-plot-grids-of-fit-results-grouped-according-to-input-model-parameters-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Functions to plot grids of fit results grouped according to input model parameters</a></div><div class="lev1 toc-item"><a href="#Grouped-Plots" data-toc-modified-id="Grouped-Plots-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Grouped Plots</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-stellar-population-AGE" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-stellar-population-AGE-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by stellar population AGE</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-stellar-population-AGE" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-stellar-population-AGE-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by stellar population AGE</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-starburst-duration-TAU" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-starburst-duration-TAU-63"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by starburst duration TAU</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-starburst-duration-TAU" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-starburst-duration-TAU-64"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by starburst duration TAU</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-METALLICITY_INDEX" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-METALLICITY_INDEX-65"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by METALLICITY_INDEX</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-METALLICITY-INDEX" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-METALLICITY-INDEX-66"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by METALLICITY INDEX</a></div><div class="lev2 toc-item"><a href="#Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-SIGTONOISE_INDEX" data-toc-modified-id="Best-Fit-$z_{\rm-fit}$-with-all-true-$z_{\rm-true}$-values-overlaid-grouped-by-SIGTONOISE_INDEX-67"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by SIGTONOISE_INDEX</a></div><div class="lev2 toc-item"><a href="#Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-SIGTONOISE_INDEX" data-toc-modified-id="Difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-values-grouped-by-SIGTONOISE_INDEX-68"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by SIGTONOISE_INDEX</a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SP-AGE-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SP-AGE-and-$z_{\rm-true}$-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus SP AGE and $z_{\rm true}$</a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-METALLICITY_INDEX-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-METALLICITY_INDEX-and-$z_{\rm-true}$-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus METALLICITY_INDEX and $z_{\rm true}$</a></div><div class="lev1 toc-item"><a href="#Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SIGTONOISE_INDEX-and-$z_{\rm-true}$" data-toc-modified-id="Plots-of-summary-statistics-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-SIGTONOISE_INDEX-and-$z_{\rm-true}$-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus SIGTONOISE_INDEX and $z_{\rm true}$</a></div><div class="lev3 toc-item"><a href="#Note-on-MEDIAN-statistic" data-toc-modified-id="Note-on-MEDIAN-statistic-901"><span class="toc-item-num">9.0.1&nbsp;&nbsp;</span>Note on MEDIAN statistic</a></div><div class="lev1 toc-item"><a href="#Categorized-plots-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-$z_{\rm-true}$-and-$z_{\rm-true}$" data-toc-modified-id="Categorized-plots-of-difference-($\frac{z_{\rm-fit}---z_{\rm-true}}{1+z_{\rm-true}}$)-versus-$z_{\rm-true}$-and-$z_{\rm-true}$-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Categorized plots of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus $z_{\rm true}$ and $z_{\rm true}$</a></div><div class="lev2 toc-item"><a href="#SIGTONOISE_INDEX-($i_{\rm-SN}$)" data-toc-modified-id="SIGTONOISE_INDEX-($i_{\rm-SN}$)-101"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>SIGTONOISE_INDEX ($i_{\rm SN}$)</a></div><div class="lev2 toc-item"><a href="#METALLICITY_INDEX-($i_{\rm-Z/Z_{\odot}}$)" data-toc-modified-id="METALLICITY_INDEX-($i_{\rm-Z/Z_{\odot}}$)-102"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>METALLICITY_INDEX ($i_{\rm Z/Z_{\odot}}$)</a></div>

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as mplplot
import astropy.io.fits as astrofits
from IPython.core.display import display
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
redshiftFitsFiles = {'ROI' : '../modelFitResults/regular_zgrid_model_redshift_fits', 
                     'CONTAM' : '../modelFitResults/regular_zgrid_model_redshift_fits_contam' }
data = np.loadtxt(redshiftFitsFiles['CONTAM'])

# %%
dataSeries = pd.Series(data)

# %%
permutationFiles = {'ROI' : '../modelFitResults/regular_zgrid_model_data/permutations_3', 
                    'CONTAM' : '../modelFitResults/regular_zgrid_model_data_contam/permutations_4'}
permutationData = np.loadtxt(permutationFiles['CONTAM'])

# %%
permutationDataFrame = pd.DataFrame(permutationData, columns=['METALLICITY_INDEX','AGE', 'TAU','REDSHIFT', 'SIGTONOISE_INDEX'])
display(permutationDataFrame)
# Out:
#       METALLICITY_INDEX    AGE   TAU  REDSHIFT  SIGTONOISE_INDEX
# 0                   1.0  1.000  0.05     0.075               0.0
# 1                   1.0  1.375  0.05     0.075               0.0
# 2                   1.0  1.750  0.05     0.075               0.0
# 3                   1.0  2.125  0.05     0.075               0.0
# 4                   1.0  2.500  0.05     0.075               0.0
# 5                   2.0  1.000  0.05     0.075               0.0
# 6                   2.0  1.375  0.05     0.075               0.0
# 7                   2.0  1.750  0.05     0.075               0.0
# 8                   2.0  2.125  0.05     0.075               0.0
# 9                   2.0  2.500  0.05     0.075               0.0
# 10                  4.0  1.000  0.05     0.075               0.0
# 11                  4.0  1.375  0.05     0.075               0.0
# 12                  4.0  1.750  0.05     0.075               0.0
# ...

# %%
tauValues = np.unique(permutationDataFrame.TAU)
ageValues = np.unique(permutationDataFrame.AGE)
metallicityIndices = np.unique(permutationDataFrame.METALLICITY_INDEX)
redshiftValues = sorted(np.unique(permutationDataFrame.REDSHIFT))
metallicityValues = {0: 0.0001,1: 0.0004, 2: 0.004, 3: 0.008, 4: 0.02, 5: 0.05, 6: 0.1}
sigToNoiseValues = {0 : 2.0, 1: 3.0, 2: 4.0, 3: 5.0, 4: 6.0}

print(tauValues, ageValues, metallicityValues, redshiftValues, sigToNoiseValues)
# Out:
# [ 0.05  0.1   0.15  0.2 ] [ 1.     1.375  1.75   2.125  2.5  ] {0: 0.0001, 1: 0.0004, 2: 0.004, 3: 0.008, 4: 0.02, 5: 0.05, 6: 0.1} [0.074999999999999997, 0.14999999999999999, 0.22499999999999998, 0.29999999999999999, 0.375, 0.45000000000000001, 0.52499999999999991, 0.59999999999999998, 0.67499999999999993, 0.74999999999999989, 0.82499999999999996, 0.89999999999999991, 0.97499999999999987, 2.5750000000000002, 2.6500000000000004, 2.7250000000000005, 2.8000000000000007, 2.8750000000000009, 2.9500000000000011] {0: 2.0, 1: 3.0, 2: 4.0, 3: 5.0, 4: 6.0}

# %% [markdown]
# # Initial plot of fit results
# True redshift values are overlaid as vertical red lines.

# %%
dataSeriesAxes = dataSeries.plot.hist(bins=100, histtype='step', fill=True, alpha=0.2)
dataSeriesAxes.vlines(np.unique(permutationDataFrame.REDSHIFT), ymin=dataSeriesAxes.get_ylim()[0], ymax=dataSeriesAxes.get_ylim()[1], colors='r')

# %% [markdown]
# ### Similar plot with restricted reshift range

# %%
dataSeriesAxes = dataSeries.plot.hist(bins=50, histtype='step', fill=True, alpha=0.2, range=(0.9, 2.6))
dataSeriesAxes.vlines(np.unique(permutationDataFrame.REDSHIFT), ymin=dataSeriesAxes.get_ylim()[0], ymax=dataSeriesAxes.get_ylim()[1], colors='r')

# %% [markdown]
# # Compute and plot difference between true and best fit redshift

# %%
permutationSubsetDataFrame = permutationDataFrame.iloc[0:len(dataSeries)].copy()
permutationSubsetDataFrame['BEST_FIT_REDSHIFT'] = dataSeries
permutationSubsetDataFrame['DELTA'] = (permutationSubsetDataFrame.BEST_FIT_REDSHIFT - permutationSubsetDataFrame.REDSHIFT)/(1 + permutationSubsetDataFrame.REDSHIFT)
deltaAxes = permutationSubsetDataFrame.DELTA.plot.hist(bins=100, histtype='step', fill=True, alpha=0.2)
deltaAxes.set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=15)
deltaDataCut = (permutationSubsetDataFrame.DELTA < 0.1) & (permutationSubsetDataFrame.DELTA > 0) & (permutationSubsetDataFrame.AGE > 3.5)
#display(permutationSubsetDataFrame[deltaDataCut])
#print(permutationSubsetDataFrame[deltaDataCut].index)

#display(permutationSubsetDataFrame.iloc[1060])

# %% [markdown]
# # Functions to plot grids of fit results grouped according to input model parameters

# %%
def genGroupedRedshiftFitSubplots(data, groupbyCol, redshifts, groupByColUnit = None, restrictToModelledRedshifts = False):
    redshiftRange = (0, 5) if not restrictToModelledRedshifts else (np.amin(np.unique(redshifts)) - 0.1, np.amax(np.unique(redshifts))+0.1)
    supTitlePrefix = '' if not restrictToModelledRedshifts else 'Redshift range restricted to modelled values. '
    grouped = data.groupby(groupbyCol)
    numGroups = grouped.ngroups
    # make subplots with three plots per row and as many rows as required
    numRows = np.ceil(numGroups/3)
    figure, axes = mplplot.subplots(figsize=(9,3*numRows), 
                                    nrows=int(numRows), 
                                    ncols=3)
    for plotIndex, (groupKey, plotAxis) in enumerate(zip(sorted(grouped.groups.keys()), axes.flatten())) :
        grouped.get_group(groupKey).BEST_FIT_REDSHIFT.plot.hist(ax=plotAxis, histtype='step', fill=True, alpha=0.2, bins=50, range=redshiftRange)
        plotAxis.set_title('{} = {:4.2f} {}'.format(groupbyCol, groupKey, groupByColUnit if groupByColUnit is not None else ''))
        plotAxis.set_xlabel('Best Fit Redshift')
        plotAxis.vlines(redshifts, ymin=plotAxis.get_ylim()[0], ymax=plotAxis.get_ylim()[1], colors='r')

    mplplot.suptitle(supTitlePrefix + groupbyCol, y=1.01)
    mplplot.tight_layout()
    
def genGroupedRedshiftFitDeltaSubplots(data, groupbyCol, redshifts, groupByColUnit = None):
    grouped = data.groupby(groupbyCol)
    numGroups = grouped.ngroups
    # make subplots with three plots per row and as many rows as required
    numRows = np.ceil(numGroups/3)
    figure, axes = mplplot.subplots(figsize=(9,3*numRows), 
                                    nrows=int(numRows), 
                                    ncols=3)
    for plotIndex, (groupKey, plotAxis) in enumerate(zip(sorted(grouped.groups.keys()), axes.flatten())) :
        grouped.get_group(groupKey).DELTA.plot.hist(ax=plotAxis, histtype='step', fill=True, alpha=0.2, bins=50)
        plotAxis.set_title('{} = {:4.2f} {}'.format(groupbyCol, groupKey, groupByColUnit if groupByColUnit is not None else ''))
        plotAxis.set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=15)
        
    mplplot.suptitle(groupbyCol, y=1.01)
    mplplot.tight_layout()

# %% [markdown]
# # Grouped Plots
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by stellar population AGE

# %%
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "AGE", np.unique(permutationDataFrame.REDSHIFT.values), "Gyr")
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "AGE", np.unique(permutationDataFrame.REDSHIFT.values), "Gyr", restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by stellar population AGE

# %%
genGroupedRedshiftFitDeltaSubplots(permutationSubsetDataFrame, "AGE", np.unique(permutationDataFrame.REDSHIFT.values), "Gyr")

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by starburst duration TAU

# %%
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "TAU", np.unique(permutationDataFrame.REDSHIFT.values), 'Gyr')
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "TAU", np.unique(permutationDataFrame.REDSHIFT.values), 'Gyr', restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by starburst duration TAU

# %%
genGroupedRedshiftFitDeltaSubplots(permutationSubsetDataFrame, "TAU", np.unique(permutationDataFrame.REDSHIFT.values), 'Gyr')

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by METALLICITY_INDEX
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "METALLICITY_INDEX", np.unique(permutationDataFrame.REDSHIFT.values))
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "METALLICITY_INDEX", np.unique(permutationDataFrame.REDSHIFT.values), restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by METALLICITY INDEX
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genGroupedRedshiftFitDeltaSubplots(permutationSubsetDataFrame, "METALLICITY_INDEX", np.unique(permutationDataFrame.REDSHIFT.values))

# %% [markdown]
# ## Best Fit $z_{\rm fit}$ with all true $z_{\rm true}$ values overlaid grouped by SIGTONOISE_INDEX
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$

# %%
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "SIGTONOISE_INDEX", np.unique(permutationDataFrame.REDSHIFT.values))
genGroupedRedshiftFitSubplots(permutationSubsetDataFrame, "SIGTONOISE_INDEX", np.unique(permutationDataFrame.REDSHIFT.values), restrictToModelledRedshifts = True)

# %% [markdown]
# ## Difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) values grouped by SIGTONOISE_INDEX
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$

# %%
genGroupedRedshiftFitDeltaSubplots(permutationSubsetDataFrame, "SIGTONOISE_INDEX", np.unique(permutationDataFrame.REDSHIFT.values))

# %% [markdown]
# # Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus SP AGE and $z_{\rm true}$

# %%
absmax = lambda x : np.max(np.abs(x))

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, absmax], ['MEAN', 'MEDIAN', 'ABSMAX'], deltaStatsAxes.flatten())):
    axes = permutationSubsetDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='AGE', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('SP Age (Gyr)')

mplplot.tight_layout()

# %% [markdown]
# # Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus METALLICITY_INDEX and $z_{\rm true}$
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, absmax], ['MEAN', 'MEDIAN', 'ABSMAX'], deltaStatsAxes.flatten())):
    axes = permutationSubsetDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='METALLICITY_INDEX', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('METALLICITY INDEX')

mplplot.tight_layout()

# %% [markdown]
# # Plots of summary statistics of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus SIGTONOISE_INDEX and $z_{\rm true}$
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$
#
# ### Note on MEDIAN statistic
# For the lowest signal-to-noise level the median `DELTA` is close to zero for all true redshift values. This is likely due to a markedly increased number of fitted redshifts that are higher than the true value for this S/N level.

# %%
deltaStatsFigure, deltaStatsAxes = mplplot.subplots(figsize=(12, 4),
                                                   ncols=3,
                                                   nrows=1)
for axisIndex, (function, title, axis) in enumerate(zip([np.mean, np.median, absmax], ['MEAN', 'MEDIAN', 'ABSMAX'], deltaStatsAxes.flatten())):
    axes = permutationSubsetDataFrame.plot.hexbin(ax=axis, x='REDSHIFT', y='SIGTONOISE_INDEX', C='DELTA', gridsize=10, reduce_C_function=function, cmap='viridis', sharex=False)
    axes.set_title('{} DELTA'.format(title))
    axes.set_xlabel(r'$z_{\rm true}$', size=15)
    axes.set_ylabel('SIGTONOISE INDEX')

mplplot.tight_layout()

# %% [markdown]
# # Categorized plots of difference ($\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$) versus $z_{\rm true}$ and $z_{\rm true}$

# %%
def genCategorizedZVersusDeltaPlots(data, categoryColumn, categoryLabelFunctor, colorMapName = 'viridis') :
    figure, axes = mplplot.subplots(figsize=(16, 8),
                                    ncols=2,
                                    nrows=1)

    groupedData = data.groupby(categoryColumn)
    colourMap = matplotlib.cm.get_cmap(colorMapName)
    indices = np.unique(data[categoryColumn].values)
    minIndex, maxIndex = np.amax(indices), np.amin(indices)
    groupColours = {int(index) : colourMap((index-minIndex)/(maxIndex - minIndex)) for index in indices} 

    for key, group in groupedData:
        group.plot.scatter(ax=axes[0], x='DELTA', y='BEST_FIT_REDSHIFT', logx=False, label=categoryLabelFunctor(key), s=20, color=groupColours[int(key)])
        group.plot.scatter(ax=axes[1], x='DELTA', y='REDSHIFT', logx=False, label=categoryLabelFunctor(key), s=20, color=groupColours[int(key)])

    deltaStatsAxes[0].set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=20)    
    deltaStatsAxes[1].set_xlabel(r'$\frac{z_{\rm fit} - z_{\rm true}}{1+z_{\rm true}}$', size=20) 

    deltaStatsAxes[0].set_ylabel(r'$z_{\rm fit}$', size=20)    
    deltaStatsAxes[1].set_ylabel(r'$z_{\rm true}$', size=20)  

    mplplot.tight_layout()

# %% [markdown]
# ## SIGTONOISE_INDEX ($i_{\rm SN}$)
# Index maps to S/N (Measured for the 3-pixel resolution element located at the central wavelength of the **G141** grism) according to:
#
# $0\rightarrow 2, 1\rightarrow 3, 2\rightarrow 4, 3\rightarrow 5, 4\rightarrow 6$

# %%
genCategorizedZVersusDeltaPlots(permutationSubsetDataFrame, 'SIGTONOISE_INDEX', lambda key : '$i_{} = ${}'.format(r'{\rm SN}',int(key)))

# %% [markdown]
# ## METALLICITY_INDEX ($i_{\rm Z/Z_{\odot}}$)
# Index maps to metallicity (as a fraction of $Z_{\odot}$) according to:
#
# $0\rightarrow 0.0001, 1\rightarrow 0.0004, 2\rightarrow 0.004, 3\rightarrow 0.008, 4\rightarrow 0.02, 5\rightarrow 0.05, 6\rightarrow 0.1$

# %%
genCategorizedZVersusDeltaPlots(permutationSubsetDataFrame, 'METALLICITY_INDEX', lambda key : '$i_{} = ${}'.format(r'{\rm Z/Z_{\odot}}',int(key)))
